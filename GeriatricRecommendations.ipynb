# %% [markdown]
# ##### Step - 1 Opening The File And Parsing Contents Into Pandas DataFrame ####

# %%
#Defining Function For Rating Data Correction
def rating_num_correction(ratings):
    ratings = ratings.split()
    return ratings[3]

# %%
#Defining Function To Parse Fields
def parse_fields(novel_data):
    return {
        "url": novel_data["url"],
        "title": novel_data["title"],
        "ratings": rating_num_correction(novel_data["rating"]),
        "cover": novel_data["image"]
    }

# %%
#Creating A List Of Dictionaries To Make A Pandas DataFrame
import json 

Books = []
with open('noveldata.json','r',encoding='utf8') as f:
    data = f.read()
    noveldata = json.loads(data)
    i = 0
    while i!= len(noveldata)-1:
        fields = parse_fields(noveldata[i])
        try:
            ratings = int(fields["ratings"])
        except ValueError:
            continue
        if ratings>10: #Filtering Out Books With <10 Ratings
            Books.append(fields)
        i = i + 1

import pandas as pd
titles = pd.DataFrame.from_dict(Books)

# %%
#Cleaning Up User Interaction Json Data 
import json
with open('userinteraction.json','r',encoding='utf8') as f:
    noveldata = f.read()
json_novel_data = json.loads(noveldata)
noveldata = json.loads(noveldata)[0]
userdata = []
j = 0
while j!= len(noveldata["user_interaction"])-1:
    userdata.append({'bookurl': noveldata["url"], 'userurl':noveldata["user_interaction"][j][2], 'username': noveldata["user_interaction"][j][1],'rating':noveldata["user_interaction"][j][0]})
    j = j+1

def userdatacorrection(file):
    userdata = []
    with open(file,'r',encoding='utf8') as f:
        data = f.read()
        noveldata = json.loads(data)
    i = 0
    while i <len(noveldata):
        j = 0
        while j<len(noveldata[i]["user_interaction"]):
            userdata.append({'bookurl': noveldata[i]["url"], 'userurl':noveldata[i]["user_interaction"][j][2], 'username': noveldata[i]["user_interaction"][j][1],'rating':noveldata[i]["user_interaction"][j][0]})
            j = j+1
        i = i+1
    return userdata

import pandas as pd
user_interaction = pd.DataFrame.from_dict(userdatacorrection('userinteraction.json'))
user_interaction.to_csv("userinteractiondata.csv")

# %%
#Cleaning Up The Search Range 
titles["ratings"] = pd.to_numeric(titles["ratings"])
titles["reduced_titles"] = titles["title"].str.replace("[^a-zA-z0-9]","", regex=True)
titles["reduced_titles"] = titles["reduced_titles"].str.lower()
titles["reduced_titles"] = titles["reduced_titles"].str.replace("\s+"," ", regex = True)
titles = titles[titles["reduced_titles"].str.len()>0]
titles["ratings"] = pd.to_numeric(titles["ratings"])
titles.to_json("books_titles.json")
titles
# Out:
#                                                      url  \
# 0      https://www.novelupdates.com/series/taming-the...
# 1      https://www.novelupdates.com/series/the-main-h...
# 2      https://www.novelupdates.com/series/the-regres...
# 3      https://www.novelupdates.com/series/kidnapped-...
# 4      https://www.novelupdates.com/series/im-really-...
# ...                                                  ...
# 11318  https://www.novelupdates.com/series/little-ger...
# 11319  https://www.novelupdates.com/series/sword-and-...
# 11320  https://www.novelupdates.com/series/misunderst...
# 11321  https://www.novelupdates.com/series/the-queens...
# 11322  https://www.novelupdates.com/series/mary-san-c...
#
#                                                    title  ratings  \
# 0                                Taming The Villainesses      183
# 1                The Main Heroines are Trying to Kill Me      428
# 2                       The Regressed Demon Lord is Kind      529
# 3                                      Kidnapped Dragons      683
# 4                  I’m Really Not The Demon God’s Lackey      509
# ...                                                  ...      ...
# 11318             Little Ger, Slow Life in Another World       69
# 11319                                     Sword and Love       24
# 11320  Misunderstood Lousy Cop: Getting Promoted for ...       17
# 11321                                The Queen’s Husband       37
# 11322                             Mary-san Comes on Foot       74
#
#                                                    cover  \
# 0      https://cdn.novelupdates.com/images/2022/06/Ta...
# 1      https://cdn.novelupdates.com/images/2022/04/Th...
# 2      https://cdn.novelupdates.com/images/2021/06/Th...
# 3      https://cdn.novelupdates.com/images/2020/10/Ki...
# 4      https://cdn.novelupdates.com/images/2021/06/Im...
# ...                                                  ...
# 11318  https://cdn.novelupdates.com/images/2021/10/Li...
# 11319  https://cdn.novelupdates.com/images/2018/09/Sw...
# 11320  https://www.novelupdates.com/img/noimagefound.jpg
# 11321  https://cdn.novelupdates.com/images/2019/03/tq...
# 11322  https://www.novelupdates.com/img/noimagefound.jpg
#
#                                           reduced_titles
# 0                                  tamingthevillainesses
# 1                       themainheroinesaretryingtokillme
# 2                            theregresseddemonlordiskind
# 3                                       kidnappeddragons
# 4                          imreallynotthedemongodslackey
# ...                                                  ...
# 11318                    littlegerslowlifeinanotherworld
# 11319                                       swordandlove
# 11320  misunderstoodlousycopgettingpromotedforrunning...
# 11321                                   thequeenshusband
# 11322                                 marysancomesonfoot
#
# [11323 rows x 5 columns]

# %%
#Uploading The Data Frame to CSV
titles.to_csv("bookdata.csv")

# %% [markdown]
# #### Step 2 - Making A Search Engine For Searching Through The Parsed Content

# %%
#Search Engine For Title Search 
from sklearn.feature_extraction.text import TfidfVectorizer 
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(titles["reduced_titles"])
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

# %%
#HTML Elements For  Easier View
def make_clickable(val): 
    return '<a target="_blank" href="{}">NovelUpdates</a>'.format(val)

def show_image(val):
    return '<img src="{}" width=50></img>'.format(val)

def search(query,vectorizer):
    processed = re.sub("[^a-zA-Z0-9]","", query.lower())
    query_vec = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity,-5)[-5:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    return results.head(5).style.format({'url': make_clickable, 'cover':show_image })

search("Soul Of Negary", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe957_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >url</th>
#       <th class="col_heading level0 col1" >title</th>
#       <th class="col_heading level0 col2" >ratings</th>
#       <th class="col_heading level0 col3" >cover</th>
#       <th class="col_heading level0 col4" >reduced_titles</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe957_level0_row0" class="row_heading level0 row0" >8986</th>
#       <td id="T_fe957_row0_col0" class="data row0 col0" ><a target="_blank" href="https://www.novelupdates.com/series/soul-of-negary/">NovelUpdates</a></td>
#       <td id="T_fe957_row0_col1" class="data row0 col1" >Soul of Negary</td>
#       <td id="T_fe957_row0_col2" class="data row0 col2" >140</td>
#       <td id="T_fe957_row0_col3" class="data row0 col3" ><img src="https://cdn.novelupdates.com/images/2020/07/negarysoul2.jpg" width=50></img></td>
#       <td id="T_fe957_row0_col4" class="data row0 col4" >soulofnegary</td>
#     </tr>
#     <tr>
#       <th id="T_fe957_level0_row1" class="row_heading level0 row1" >3774</th>
#       <td id="T_fe957_row1_col0" class="data row1 col0" ><a target="_blank" href="https://www.novelupdates.com/series/hp1-kara-hajimeru-isekai-musou/">NovelUpdates</a></td>
#       <td id="T_fe957_row1_col1" class="data row1 col1" >HP1 kara Hajimeru Isekai Musou</td>
#       <td id="T_fe957_row1_col2" class="data row1 col2" >129</td>
#       <td id="T_fe957_row1_col3" class="data row1 col3" ><img src="https://www.novelupdates.com/img/noimagefound.jpg" width=50></img></td>
#       <td id="T_fe957_row1_col4" class="data row1 col4" >hp1karahajimeruisekaimusou</td>
#     </tr>
#     <tr>
#       <th id="T_fe957_level0_row2" class="row_heading level0 row2" >3773</th>
#       <td id="T_fe957_row2_col0" class="data row2 col0" ><a target="_blank" href="https://www.novelupdates.com/series/i-became-the-youngest-daughter-of-the-mafia-family/">NovelUpdates</a></td>
#       <td id="T_fe957_row2_col1" class="data row2 col1" >I Became the Youngest Daughter of the Mafia Family</td>
#       <td id="T_fe957_row2_col2" class="data row2 col2" >43</td>
#       <td id="T_fe957_row2_col3" class="data row2 col3" ><img src="https://cdn.novelupdates.com/images/2021/08/I-Became-the-Youngest-Daughter-of-the-Mafia-Family.jpg" width=50></img></td>
#       <td id="T_fe957_row2_col4" class="data row2 col4" >ibecametheyoungestdaughterofthemafiafamily</td>
#     </tr>
#     <tr>
#       <th id="T_fe957_level0_row3" class="row_heading level0 row3" >3772</th>
#       <td id="T_fe957_row3_col0" class="data row3 col0" ><a target="_blank" href="https://www.novelupdates.com/series/of-all-the-transmigrations-why-am-i-a-prisoner/">NovelUpdates</a></td>
#       <td id="T_fe957_row3_col1" class="data row3 col1" >Of All the Transmigrations, Why Am I a Prisoner?</td>
#       <td id="T_fe957_row3_col2" class="data row3 col2" >28</td>
#       <td id="T_fe957_row3_col3" class="data row3 col3" ><img src="https://cdn.novelupdates.com/images/2021/07/Of-all-the-Transmigrations-why-am-I-a-Prisoner_1627539664.jpg" width=50></img></td>
#       <td id="T_fe957_row3_col4" class="data row3 col4" >ofallthetransmigrationswhyamiaprisoner</td>
#     </tr>
#     <tr>
#       <th id="T_fe957_level0_row4" class="row_heading level0 row4" >3771</th>
#       <td id="T_fe957_row4_col0" class="data row4 col0" ><a target="_blank" href="https://www.novelupdates.com/series/im-an-s-class-knight-and-i-was-appointed-as-a-captain-of-an-elite-unit-but-all-my-subordinates-were-older-s-class-female-knights/">NovelUpdates</a></td>
#       <td id="T_fe957_row4_col1" class="data row4 col1" >I’m an S-class Knight, and I was Appointed as a Captain of an Elite Unit, but all my Subordinates were Older S-class Female Knights</td>
#       <td id="T_fe957_row4_col2" class="data row4 col2" >21</td>
#       <td id="T_fe957_row4_col3" class="data row4 col3" ><img src="https://www.novelupdates.com/img/noimagefound.jpg" width=50></img></td>
#       <td id="T_fe957_row4_col4" class="data row4 col4" >imansclassknightandiwasappointedasacaptainofaneliteunitbutallmysubordinateswereoldersclassfemaleknights</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Liked Books
liked_books =['https://www.novelupdates.com/series/soul-of-negary/']
titles[titles["url"].isin(liked_books)].to_csv("liked_books.csv")

# %% [markdown]
# #### Step - 3 Collaborative Filtering Model For Recommendations

# %%
#Making A Book Set Of Liked Books
import pandas as pd
my_books = pd.read_csv("liked_books.csv", index_col=0)
my_books["url"] = my_books["url"].astype(str)
book_set = set(my_books["url"])

# %%
#Data Frame For User Input Data
my_books
list1 = []
import csv
with open("liked_books.csv") as f:
    csv = csv.reader(f)
    for row in csv:
        if row[1] == "url":
            continue
        list1.append({"user_id": -1, "book_id": row[1],"rating": 5})
list1 = pd.DataFrame.from_dict(list1)

# %%
#Function To Clean Up The Dataset 
def urlcorrector(string):
    if "#comments" in string:
        string = string.rsplit("/",1)[0]
        if "comment-page" in string:
            string = string.rsplit("/",1)[0]
        string = string + "/"
    return(string)

# %%
#Finding Overlaping Users
overlap_users = {}
import csv
with open("userinteractiondata.csv") as f:
    csv = csv.reader(f)   
    for row in csv:
        url = urlcorrector(row[1])
        if url in book_set:
            if row[2] not in overlap_users:
                overlap_users[row[2]] = 1
            else:
                overlap_users[row[2]] = overlap_users[row[2]] + 1

# %%
#Filtering Users
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k]>my_books.shape[0]/10])
filtered_overlap_users
# Out:
# {'https://www.novelupdates.com/user/124334/Rextraos/',
#  'https://www.novelupdates.com/user/130085/Zeusomega/',
#  'https://www.novelupdates.com/user/138528/bhankit/',
#  'https://www.novelupdates.com/user/142575/EFermi/',
#  'https://www.novelupdates.com/user/147765/The Hamster Overlord/',
#  'https://www.novelupdates.com/user/154209/HelluvaReader/',
#  'https://www.novelupdates.com/user/15786/darthpsykoz/',
#  'https://www.novelupdates.com/user/159825/Uhoh_/',
#  'https://www.novelupdates.com/user/169770/bheyer/',
#  'https://www.novelupdates.com/user/174241/Syntheticspirit/',
#  'https://www.novelupdates.com/user/183711/Poireau/',
#  'https://www.novelupdates.com/user/214211/Subline Act/',
#  'https://www.novelupdates.com/user/264271/qonquirette/',
#  'https://www.novelupdates.com/user/268492/TKing1517/',
#  'https://www.novelupdates.com/user/271361/Daresan/',
#  'https://www.novelupdates.com/user/284417/Liero Dirlewanger/',
#  'https://www.novelupdates.com/user/322878/Alex Woods/',
#  'https://www.novelupdates.com/user/338694/cpzombie/',
#  'https://www.novelupdates.com/user/342645/Taffyman/',
#  'https://www.novelupdates.com/user/35266/Mors86/',
#  'https://www.novelupdates.com/user/367404/Nsado/',
#  'https://www.novelupdates.com/user/374944/Rambira/',
#  'https://www.novelupdates.com/user/381558/Valixiant/',
#  'https://www.novelupdates.com/user/413166/bakaemon/',
#  'https://www.novelupdates.com/user/60844/drollawake/',
#  'https://www.novelupdates.com/user/62924/ngheem/',
#  'https://www.novelupdates.com/user/76750/Gsichtselfmeter/',
#  'https://www.novelupdates.com/user/95898/Queen of Sheba/'}

# %%
#Getting Properties Of Filtered Users From User Interaction Data 
import csv
interactions_list = []
with open("userinteractiondata.csv") as f:
    userinteraction = csv.reader(f)
    for row in userinteraction:
        if row[2] in filtered_overlap_users:
             interactions_list.append([row[2],row[1],row[4]])

# %%
#Making A Pandas DataFrame of the data
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])
interactions = pd.concat([list1[["user_id", "book_id", "rating"]], interactions])

# %%
#Cleaning Up The Data
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

interactions
# Out:
#                                                 user_id  \
# 0                                                    -1
# 0     https://www.novelupdates.com/user/95898/Queen ...
# 1     https://www.novelupdates.com/user/322878/Alex ...
# 2     https://www.novelupdates.com/user/76750/Gsicht...
# 3     https://www.novelupdates.com/user/413166/bakae...
# ...                                                 ...
# 1064  https://www.novelupdates.com/user/381558/Valix...
# 1065  https://www.novelupdates.com/user/338694/cpzom...
# 1066  https://www.novelupdates.com/user/322878/Alex ...
# 1067  https://www.novelupdates.com/user/381558/Valix...
# 1068  https://www.novelupdates.com/user/130085/Zeuso...
#
#                                                 book_id  rating  user_index  \
# 0     https://www.novelupdates.com/series/soul-of-ne...       5           0
# 0     https://www.novelupdates.com/series/world-of-c...       4          28
# 1     https://www.novelupdates.com/series/return-of-...       3          17
# 2       https://www.novelupdates.com/series/overgeared/       2          27
# 3     https://www.novelupdates.com/series/the-demon-...       5          24
# ...                                                 ...     ...         ...
# 1064  https://www.novelupdates.com/series/my-house-o...       3          23
# 1065  https://www.novelupdates.com/series/my-house-o...       3          18
# 1066  https://www.novelupdates.com/series/i-have-a-s...       5          17
# 1067  https://www.novelupdates.com/series/i-have-a-s...       4          23
# 1068  https://www.novelupdates.com/series/i-have-a-s...       0           2
#
#       book_index
# 0            493
# 0            718
# 1            445
# 2            391
# 3            563
# ...          ...
# 1064         356
# 1065         358
# 1066         229
# 1067         229
# 1068         229
#
# [1070 rows x 5 columns]

# %%
#Making A Sparse Matrix
from scipy.sparse import coo_matrix
ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"],interactions["book_index"])))
ratings_mat = ratings_mat_coo.tocsr()
interactions[interactions["user_id"]=="-1"]
my_index = 0

# %%
#Cosine Similairty Match For Similar Users
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()
import numpy as np
indices = np.argpartition(similarity, -20)[-20:]

# %%
#Filtering and Cleaning Up Similar Users
similar_users = interactions[interactions["user_index"].isin(indices)].copy()
similar_users = similar_users[similar_users["user_id"]!="-1"]
similar_users
# Out:
#                                                 user_id  \
# 0     https://www.novelupdates.com/user/95898/Queen ...
# 1     https://www.novelupdates.com/user/322878/Alex ...
# 3     https://www.novelupdates.com/user/413166/bakae...
# 4     https://www.novelupdates.com/user/413166/bakae...
# 7     https://www.novelupdates.com/user/381558/Valix...
# ...                                                 ...
# 1064  https://www.novelupdates.com/user/381558/Valix...
# 1065  https://www.novelupdates.com/user/338694/cpzom...
# 1066  https://www.novelupdates.com/user/322878/Alex ...
# 1067  https://www.novelupdates.com/user/381558/Valix...
# 1068  https://www.novelupdates.com/user/130085/Zeuso...
#
#                                                 book_id  rating  user_index  \
# 0     https://www.novelupdates.com/series/world-of-c...       4          28
# 1     https://www.novelupdates.com/series/return-of-...       3          17
# 3     https://www.novelupdates.com/series/the-demon-...       5          24
# 4     https://www.novelupdates.com/series/im-really-...       5          24
# 7     https://www.novelupdates.com/series/kidnapped-...       5          23
# ...                                                 ...     ...         ...
# 1064  https://www.novelupdates.com/series/my-house-o...       3          23
# 1065  https://www.novelupdates.com/series/my-house-o...       3          18
# 1066  https://www.novelupdates.com/series/i-have-a-s...       5          17
# 1067  https://www.novelupdates.com/series/i-have-a-s...       4          23
# 1068  https://www.novelupdates.com/series/i-have-a-s...       0           2
#
#       book_index
# 0            718
# 1            445
# 3            563
# 4            246
# 7            274
# ...          ...
# 1064         356
# 1065         358
# 1066         229
# 1067         229
# 1068         229
#
# [721 rows x 5 columns]

# %% [markdown]
# #### Filtering and Displaying Top Recommendations

# %%
#Book Recommendations
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])
books_titles = pd.read_json("books_titles.json")
books_titles["url"] = books_titles["url"].astype(str)
books_recs = book_recs.merge(books_titles, how="inner",left_on ="book_id",right_on ="url")
books_recs
# Out:
#      count  mean                                                url  \
# 0        4   4.0  https://www.novelupdates.com/series/48-hours-a...
# 1        1   0.0  https://www.novelupdates.com/series/6-year-old...
# 2        1   1.0  https://www.novelupdates.com/series/80-years-o...
# 3        2   1.0  https://www.novelupdates.com/series/9-heavenly...
# 4        1   1.0  https://www.novelupdates.com/series/a-demons-p...
# ..     ...   ...                                                ...
# 233      2   4.0  https://www.novelupdates.com/series/why-fall-i...
# 234      2   1.0  https://www.novelupdates.com/series/world-of-w...
# 235      1   3.0   https://www.novelupdates.com/series/yama-rising/
# 236      2   5.0  https://www.novelupdates.com/series/you-cannot...
# 237      2   1.0  https://www.novelupdates.com/series/youkoso-ji...
#
#                                                  title  ratings  \
# 0                                       48 Hours a Day      132
# 1       6-year-old Wise Man Wants to Walk in the Shade       51
# 2    80 Years Of Signing-In At The Cold Palace, I A...       36
# 3                            9 Heavenly Thunder Manual      338
# 4                                       A Demon’s Path       73
# ..                                                 ...      ...
# 233  Why Fall in Love if You Can Attend Tsinghua Un...      356
# 234        World of Warcraft: Foreign Realm Domination      423
# 235                                        Yama Rising       89
# 236               You Cannot Afford To Offend My Woman      270
# 237    Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e      532
#
#                                                  cover  \
# 0    https://cdn.novelupdates.com/images/2021/06/Ho...
# 1    https://cdn.novelupdates.com/images/2020/07/91...
# 2    https://cdn.novelupdates.com/images/2021/09/Ye...
# 3    https://cdn.novelupdates.com/images/2015/07/9m...
# 4    https://cdn.novelupdates.com/images/2017/11/11...
# ..                                                 ...
# 233  https://cdn.novelupdates.com/images/2020/05/Ts...
# 234  https://cdn.novelupdates.com/images/2017/07/wo...
# 235  https://cdn.novelupdates.com/images/2020/08/Ya...
# 236  https://cdn.novelupdates.com/images/2019/03/yc...
# 237  https://cdn.novelupdates.com/images/2017/02/co...
#
#                                      reduced_titles
# 0                                       48hoursaday
# 1              6yearoldwisemanwantstowalkintheshade
# 2    80yearsofsigninginatthecoldpalaceiamunrivalled
# 3                            9heavenlythundermanual
# 4                                       ademonspath
# ..                                              ...
# 233   whyfallinloveifyoucanattendtsinghuauniversity
# 234           worldofwarcraftforeignrealmdomination
# 235                                      yamarising
# 236                  youcannotaffordtooffendmywoman
# 237       youkosojitsuryokushijoushuginokyoushitsue
#
# [238 rows x 7 columns]

# %%
#Filtering and Cleaning Up Book Recommendations
books_recs["ratings"] = books_recs["ratings"].astype(int)
books_recs["adjusted_count"] = books_recs["count"]**(books_recs["count"] / books_recs["ratings"])
books_recs["score"] = books_recs["mean"]*books_recs["adjusted_count"]
books_recs = books_recs[~books_recs["url"].isin(my_books["url"])]
my_books["reduced_titles"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()
my_books["reduced_titles"] = my_books["reduced_titles"].str.replace("\s+"," ", regex=True)
books_recs = books_recs[~books_recs["reduced_titles"].isin(my_books["reduced_titles"])]
books_recs = books_recs[books_recs["count"]>1]
books_recs = books_recs[books_recs["mean"]>1]
top_recs = books_recs.sort_values("score", ascending=False)

# %%
#Displaying Top Recommendations
def make_clickable(val):
    return '<a target="_blank" href="{}">NovelUpdates</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

top_recs.style.format({'url': make_clickable, 'cover': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_1cfa2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >url</th>
#       <th class="col_heading level0 col3" >title</th>
#       <th class="col_heading level0 col4" >ratings</th>
#       <th class="col_heading level0 col5" >cover</th>
#       <th class="col_heading level0 col6" >reduced_titles</th>
#       <th class="col_heading level0 col7" >adjusted_count</th>
#       <th class="col_heading level0 col8" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1cfa2_level0_row0" class="row_heading level0 row0" >172</th>
#       <td id="T_1cfa2_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_1cfa2_row0_col1" class="data row0 col1" >5.000000</td>
#       <td id="T_1cfa2_row0_col2" class="data row0 col2" ><a target="_blank" href="https://www.novelupdates.com/series/surviving-a-shounen-manga/">NovelUpdates</a></td>
#       <td id="T_1cfa2_row0_col3" class="data row0 col3" >Surviving a Shounen Manga</td>
#       <td id="T_1cfa2_row0_col4" class="data row0 col4" >130</td>
#       <td id="T_1cfa2_row0_col5" class="data row0 col5" ><a href="https://cdn.novelupdates.com/images/2021/10/Surviving-a-Shounen-Manga_1633964212.jpg"><img src="https://cdn.novelupdates.com/images/2021/10/Surviving-a-Shounen-Manga_1633964212.jpg" width=50></img></a></td>
#       <td id="T_1cfa2_row0_col6" class="data row0 col6" >survivingashounenmanga</td>
#       <td id="T_1cfa2_row0_col7" class="data row0 col7" >1.043578</td>
#       <td id="T_1cfa2_row0_col8" class="data row0 col8" >5.217890</td>
#     </tr>
#     <tr>
#       <th id="T_1cfa2_level0_row1" class="row_heading level0 row1" >203</th>
#       <td id="T_1cfa2_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_1cfa2_row1_col1" class="data row1 col1" >5.000000</td>
#       <td id="T_1cfa2_row1_col2" class="data row1 col2" ><a target="_blank" href="https://www.novelupdates.com/series/the-protagonists-are-murdered-by-me/">NovelUpdates</a></td>
#       <td id="T_1cfa2_row1_col3" class="data row1 col3" >The Protagonists Are Murdered by Me</td>
#       <td id="T_1cfa2_row1_col4" class="data row1 col4" >311</td>
#       <td id="T_1cfa2_row1_col5" class="data row1 col5" ><a href="https://cdn.novelupdates.com/images/2021/03/The-Protagonists-Are-Murdered-by-Me.jpg"><img src="https://cdn.novelupdates.com/images/2021/03/The-Protagonists-Are-Murdered-by-Me.jpg" width=50></img></a></td>
#       <td id="T_1cfa2_row1_col6" class="data row1 col6" >theprotagonistsaremurderedbyme</td>
#       <td id="T_1cfa2_row1_col7" class="data row1 col7" >1.017990</td>
#       <td id="T_1cfa2_row1_col8" class="data row1 col8" >5.089950</td>
#     </tr>
#     <tr>
#       <th id="T_1cfa2_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_1cfa2_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_1cfa2_row2_col1" class="data row2 col1" >5.000000</td>
#       <td id="T_1cfa2_row2_col2" class="data row2 col2" ><a target="_blank" href="https://www.novelupdates.com/series/ascending-the-heavens-as-an-evil-god/">NovelUpdates</a></td>
#       <td id="T_1cfa2_row2_col3" class="data row2 col3" >Ascending the Heavens as an Evil God</td>
#       <td id="T_1cfa2_row2_col4" class="data row2 col4" >90</td>
#       <td id="T_1cfa2_row2_col5" class="data row2 col5" ><a href="https://cdn.novelupdates.com/images/2021/04/Ascending-The-Heavens-As-An-Evil-God.jpg"><img src="https://cdn.novelupdates.com/images/2021/04/Ascending-The-Heavens-As-An-Evil-God.jpg" width=50></img></a></td>
#       <td id="T_1cfa2_row2_col6" class="data row2 col6" >ascendingtheheavensasanevilgod</td>
#       <td id="T_1cfa2_row2_col7" class="data row2 col7" >1.015523</td>
#       <td id="T_1cfa2_row2_col8" class="data row2 col8" >5.077613</td>
#     </tr>
#     <tr>
#       <th id="T_1cfa2_level0_row3" class="row_heading level0 row3" >137</th>
#       <td id="T_1cfa2_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_1cfa2_row3_col1" class="data row3 col1" >5.000000</td>
#       <td id="T_1cfa2_row3_col2" class="data row3 col2" ><a target="_blank" href="https://www.novelupdates.com/series/power-and-wealth/">NovelUpdates</a></td>
#       <td id="T_1cfa2_row3_col3" class="data row3 col3" >Power and Wealth</td>
#       <td id="T_1cfa2_row3_col4" class="data row3 col4" >103</td>
#       <td id="T_1cfa2_row3_col5" class="data row3 col5" ><a href="https://cdn.novelupdates.com/images/2019/03/cover-image.jpg"><img src="https://cdn.novelupdates.com/images/2019/03/cover-image.jpg" width=50></img></a></td>
#       <td id="T_1cfa2_row3_col6" class="data row3 col6" >powerandwealth</td>
#       <td id="T_1cfa2_row3_col7" class="data row3 col7" >1.013550</td>
#       <td id="T_1cfa2_row3_col8" class="data row3 col8" >5.067751</td>
#     </tr>
#     <tr>
#       <th id="T_1cfa2_level0_row4" class="row_heading level0 row4" >158</th>
#       <td id="T_1cfa2_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_1cfa2_row4_col1" class="data row4 col1" >5.000000</td>
#       <td id="T_1cfa2_row4_col2" class="data row4 col2" ><a target="_blank" href="https://www.novelupdates.com/series/shepherding-humanity/">NovelUpdates</a></td>
#       <td id="T_1cfa2_row4_col3" class="data row4 col3" >Shepherding Humanity</td>
#       <td id="T_1cfa2_row4_col4" class="data row4 col4" >109</td>
#       <td id="T_1cfa2_row4_col5" class="data row4 col5" ><a href="https://cdn.novelupdates.com/images/2020/06/shepherdinghumanity4.jpg"><img src="https://cdn.novelupdates.com/images/2020/06/shepherdinghumanity4.jpg" width=50></img></a></td>
#       <td id="T_1cfa2_row4_col6" class="data row4 col6" >shepherdinghumanity</td>
#       <td id="T_1cfa2_row4_col7" class="data row4 col7" >1.012800</td>
#       <td id="T_1cfa2_row4_col8" class="data row4 col8" >5.063998</td>
#     </tr>
#     <tr>
#       <th id="T_1cfa2_level0_row5" class="row_heading level0 row5" >106</th>
#       <td id="T_1cfa2_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_1cfa2_row5_col1" class="data row5 col1" >5.000000</td>
#       <td id="T_1cfa2_row5_col2" class="data row5 col2" ><a target="_blank" href="https://www.novelupdates.com/series/low-dimensional-game/">NovelUpdates</a></td>
#       <td id="T_1cfa2_row5_col3" class="data row5 col3" >Low Dimensional Game</td>
#       <td id="T_1cfa2_row5_col4" class="data row5 col4" >110</td>
#       <td id="T_1cfa2_row5_col5" class="data row5 col5" ><a href="https://cdn.novelupdates.com/images/2019/04/Low-Dimensional-Game.jpg"><img src="https://cdn.novelupdates.com/images/2019/04/Low-Dimensional-Game.jpg" width=50></img></a></td>
#       <td id="T_1cfa2_row5_col6" class="data row5 col6" >lowdimensionalgame</td>
#       <td id="T_1cfa2_row5_col7" class="data row5 col7" >1.012682</td>
#       <td id="T_1cfa2_row5_col8" class="data row5 col8" >5.063412</td>
#     </tr>
#     <tr>
#       <th id="T_1cfa2_level0_row6" class="row_heading level0 row6" >111</th>
#       <td id="T_1cfa2_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_1cfa2_row6_col1" class="data row6 col1" >5.000000</td>
#       <td id="T_1cfa2_row6_col2" class="data row6 col2" ><a target="_blank" href="https://www.novelupdates.com/series/master-of-untold-daos/">NovelUpdates</a></td>
#       <td id="T_1cfa2_row6_col3" class="data row6 col3" >Master of Untold Daos</td>
#       <td id="T_1cfa2_row6_col4" class="data row6 col4" >112</td>
#       <td id="T_1cfa2_row6_col5" class="data row6 col5" ><a href="https://cdn.novelupdates.com/images/2021/01/Master-of-Untold-Daos.jpg"><img src="https://cdn.novelupdates.com/images/2021/01/Master-of-Untold-Daos.jpg" width=50></img></a></td>
#       <td id="T_1cfa2_row6_col6" class="data row6 col6" >masterofuntolddaos</td>
#       <td id="T_1cfa2_row6_col7" class="data row6 col7" >1.012455</td>
#       <td id="T_1cfa2_row6_col8" class="data row6 col8" >5.062273</td>
#     </tr>
#     <tr>
#       <th id="T_1cfa2_level0_row7" class="row_heading level0 row7" >149</th>
#       <td id="T_1cfa2_row7_col0" class="data r
